# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
response = requests.get(url)
data = response.json()

# %%
# 2) Seu código aqui
df = pd.DataFrame(data['items'])
df
# Out:
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0         33451        Município  Flor da Serra do Sul   4107850  PR
# 1         33998        Município            Entre Rios   4205175  SC
# 2         34000        Município       Mogi das Cruzes   3530607  SP
# 3         34522        Município          Major Vieira   4210308  SC
# 4         43021        Município               Eusébio   2304285  CE
# ...         ...              ...                   ...       ...  ..
# 4995       7159           Estado               Alagoas        27  AL
# 4996       7160        Município               Ervália   3124005  MG
# 4997       7163        Município          São Domingos   2928950  BA
# 4998       7174        Município             Cristália   3120300  MG
# 4999       7177        Município            São Carlos   4216008  SC
#
#                    num_pvl                                             status  \
# ...

# %%
# 3) Seu código aqui
df_rj = df[df['uf'] == 'RJ']
df_rj
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 172       33609        Município       Vassouras   3306206  RJ
# 206       28822        Município         Resende   3304201  RJ
# 485       11005        Município        Araruama   3300209  RJ
# 617       13780        Município   Nova Friburgo   3303401  RJ
# 625       12509        Município   Volta Redonda   3306305  RJ
# ...         ...              ...             ...       ...  ..
# 4690      13483           Estado  Rio de Janeiro        33  RJ
# 4698      11581        Município    Belford Roxo   3300456  RJ
# 4912      11419        Município  Rio de Janeiro   3304557  RJ
# 4939       9102           Estado  Rio de Janeiro        33  RJ
# 4940      11589        Município         Niterói   3303302  RJ
#
#                    num_pvl                                             status  \
# 172   PVL02.002481/2019-96                                           Deferido
# ...

# %%
top_status = df_rj['status'].value_counts().head(3)

print("Três status mais frequentes:")
print(top_status)
# Out:
# Três status mais frequentes:
# status
# Deferido                                                 26
# Arquivado                                                12
# Encaminhado à PGFN com manifestação técnica favorável    10
# Name: count, dtype: int64

# %%
df_rj['ano_status'] = df_rj['data_status'].str.slice(0, 4)
frequencia_ano_status = df_rj['ano_status'].value_counts()

print("\nFrequência de cada ano do campo construído:")
print(frequencia_ano_status)
# Out:
# Frequência de cada ano do campo construído:
# ano_status
# 27/0    5
# 06/0    4
# 09/0    4
# 29/0    4
# 30/1    4
# 12/0    4
# 13/0    3
# 31/0    2
# 30/0    2
# 27/1    2
# 15/0    2
# 21/1    2
# 25/0    2
# 28/0    2
# 20/0    2
# 21/0    2
# 04/0    2
# 23/0    1
# 01/1    1
# 01/0    1
# 03/0    1
# 02/0    1
# 16/0    1
# 18/1    1
# 19/1    1
# 22/0    1
# 22/1    1
# 23/1    1
# 20/1    1
# 18/0    1
# 11/0    1
# 10/1    1
# 31/1    1
# 06/1    1
# 08/0    1
# 26/0    1
# 17/0    1
# Name: count, dtype: int64
# C:\Users\jcpmp\AppData\Local\Temp\ipykernel_19812\3576957916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rj['ano_status'] = df_rj['data_status'].str.slice(0, 4)

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consultar_api(uf, tipo_interessado):
    url = f"https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
    params = {'uf': uf, 'tipo_interessado': tipo_interessado}
    
    response = requests.get(url, params=params)
    data = response.json()
    
    df = pd.DataFrame(data['items'])
    return df

# %%
# 2) Seu código aqui
df_mg_arquivado = consultar_api(uf='MG', tipo_interessado='Estado')
count_mg_arquivado = df_mg_arquivado[df_mg_arquivado['status'] == 'Arquivado por decurso de prazo'].shape[0]
print(f"Solicitações para o Estado de Minas Gerais com status 'Arquivado por decurso de prazo': {count_mg_arquivado}")
# Out:
# Solicitações para o Estado de Minas Gerais com status 'Arquivado por decurso de prazo': 1

# %%
# 3) Seu código aqui

# Não consegui localizar onde está o erro
df_bahia_municipio = consultar_api(uf='BA', tipo_interessado='Município')
municipio_mais_deferido = df_bahia_municipio[df_bahia_municipio['status'] == 'Deferido'].groupby('nome_interessado').size().idxmax()
print(f"Município da Bahia com mais solicitações deferidas: {municipio_mais_deferido}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 5
#       1 # 3) Seu código aqui
#       2
#       3 # Não consegui localizar onde está o erro
#       4 df_bahia_municipio = consultar_api(uf='BA', tipo_interessado='Município')
# ----> 5 municipio_mais_deferido = df_bahia_municipio[df_bahia_municipio['status'] == 'Deferido'].groupby('nome_interessado').size().idxmax()
#       6 print(f"Município da Bahia com mais solicitações deferidas: {municipio_mais_deferido}")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
# ...

# %%
# 4) Seu código aqui
df_bahia_estado = consultar_api(uf='BA', tipo_interessado='Estado')
df_bahia_estado.to_csv('solicitacoes_bahia_estado.csv', index=False)
print("Arquivo CSV salvo com sucesso.")
# Out:
# Arquivo CSV salvo com sucesso.
